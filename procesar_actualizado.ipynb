# %%
from scraper_actualizado import Scraper

URLS = [
    {
        "url": "https://es.wikisource.org/wiki/Historia_de_un_amor_turbio",
        "multipagina": False
    },
    {
        "url": "https://es.wikisource.org/wiki/A_flor_de_piel",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/A_fuego_lento",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/A_los_pies_de_Venus",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/A_prueba",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/A_todo_honor",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Adem%C3%A1s_del_frac",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Aita_Tettauen",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Al_amor_de_los_tizones",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Al_primer_vuelo",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Amadeo_I",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Amalia",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Amistad_funesta",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Ana_Karenina",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/%C3%81ngel_Guerra_(Gald%C3%B3s)",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Arroz_y_tartana",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/As%C3%AD_paga_el_diablo",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Aura_o_las_violetas",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Aurora_roja",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Baile_y_cochino",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Bail%C3%A9n_(P%C3%A9rez_Gald%C3%B3s)",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Blasones_y_talegas",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Bodas_reales",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Brenda",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Buenos_Aires_en_el_a%C3%B1o_2080",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Bug-Jargal",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/C%C3%A1diz",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Camila_o_la_virtud_triunfante",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/C%C3%A1novas",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Caramur%C3%BA",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Carlos_VI_en_la_R%C3%A1pita",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Ca%C3%B1as_y_barro",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Cel%C3%ADn",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Cinco_semanas_en_globo",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Clemencia_(Altamirano)",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Clemencia_(Caballero)",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Crimen_y_castigo_(tr._an%C3%B3nima)",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Cr%C3%B3nica_del_reinado_de_Carlos_IX",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Cuesti%C3%B3n_de_ambiente",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Cumand%C3%A1",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/De_Cartago_a_Sagunto",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/De_O%C3%B1ate_a_la_Granja",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/De_tal_palo,_tal_astilla",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Del_fr%C3%ADo_al_fuego",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Don_Gonzalo_Gonz%C3%A1lez_de_la_Gonzalera",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Don_Segundo_Sombra",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Do%C3%B1a_Luz",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Do%C3%B1a_Milagros",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Do%C3%B1a_Perfecta",
        "multipagina": True
    },
    {
        "url": "https://es.wikisource.org/wiki/Dulce_due%C3%B1o_(Pardo_Baz%C3%A1n)",
        "multipagina": True
    }
]

NOMBRE_DE_CARPETA = "datos"

CABECERAS = {
    "User-Agent": "LabPLN-2026/1.0 (contacto: tu-mail@ejemplo.com)"
}

STOPWORDS = r"c:\Ciencia De Datos\NLP\pair_programming_ia\stopwords_es.txt"


def cargar_stopwords(ruta_archivo):
    """Carga el archivo de stopwords y devuelve un conjunto de palabras."""
    with open(ruta_archivo, "r", encoding="utf-8") as f:
        return {
            linea.strip().lower()
            for linea in f
            if linea.strip()
        }


def inicializar_scraper(url, nombre_archivo):
    """
    Inicializa el scraper, verifica robots.txt,
    obtiene la página principal y guarda su HTML.
    """
    scraper = Scraper(
        url,
        headers=CABECERAS,
        nombre_archivo=nombre_archivo,
        carpeta_destino=NOMBRE_DE_CARPETA
    )

    permitido = scraper.permite_scrapeo()

    if permitido:
        print(f"Scrapeo permitido por robots.txt: {permitido}")
        scraper.actualizo_csv(url, "robots", "OK")

        respuesta = scraper.obtener_pagina()

        if respuesta:
            print("Scrapeo exitoso")
            scraper.guardar_pagina()
            scraper.actualizo_csv(url, "extraccion", "OK")
            return scraper

        print("No se pudo obtener la página")
        scraper.actualizo_csv(url, "extraccion", "Error")
        return False

    print("Scrapeo no permitido")
    scraper.actualizo_csv(url, "robots", "No permitido")

    print(
        "Forzar scrapeo sin autorización de robots.txt "
        "(no recomendado) s/n:"
    )
    respuesta = input().lower()

    if respuesta == "s":
        print("Forzando scrapeo sin autorización de robots.txt")

        respuesta = scraper.obtener_pagina()

        if respuesta:
            print("Scrapeo exitoso")
            scraper.guardar_pagina()
            scraper.actualizo_csv(url, "extraccion", "OK")
            return scraper

    print("Scrapeo cancelado")
    scraper.actualizo_csv(url, "extraccion", "Cancelado")

    return False


def contar_palabra(scraper, palabra):
    """Cuenta cuántas veces aparece una palabra en la página principal."""
    cantidad = scraper.contar_palabra(palabra)

    print(
        f"La palabra '{palabra}' aparece "
        f"{cantidad} veces en la página."
    )


def main():
    """Recorre todas las obras definidas en URLS y arma el corpus."""

    stopwords = cargar_stopwords(STOPWORDS)

    for i, item in enumerate(URLS, start=1):

        url = item["url"]
        multipagina = item["multipagina"]

        print("\n" + "=" * 60)
        print(f"Procesando URL {i}:")
        print(url)
        print(f"Multipágina: {multipagina}")
        print("=" * 60)

        nombre_archivo = f"pagina_{i}.html"

        scraper = inicializar_scraper(
            url,
            nombre_archivo
        )

        if not scraper:
            print(
                "Esta URL no pudo ser procesada. "
                "Se continúa con la siguiente."
            )
            continue

        scraper.actualizo_csv(
            url,
            "multipagina",
            "Sí" if multipagina else "No"
        )

        # Los metadatos se extraen siempre de la página principal.
        datos_corpus = scraper.obtener_datos_corpus()
        
       
        scraper.actualizo_csv(
            url,
            "ruta",
            str(scraper.ruta_archivo)
        )

        scraper.actualizo_csv(
            url,
            "Titulo de la página",
            datos_corpus.get("title", "")
        )

        scraper.actualizo_csv(
            url,
            "Autoría de la página",
            datos_corpus.get("author", "")
        )

        scraper.actualizo_csv(
            url,
            "Fecha de publicación de la página",
            datos_corpus.get("date", "")
        )
        
        fecha_publicacion_obra = scraper.obtener_fecha_publicacion_obra()
        
        scraper.actualizo_csv(
            url,
            "Año de publicación de la Obra",
            fecha_publicacion_obra
        )
        
        print(f"Fecha de publicación obtenida: {fecha_publicacion_obra}")
        
        scraper.actualizo_csv(
            url,
            "Medio",
            datos_corpus.get("hostname", "")
        )

        # --------------------------------------------------------
        # ACÁ SE DECIDE EXPLÍCITAMENTE QUÉ TIPO DE SCRAPING USAR.
        # --------------------------------------------------------
        if multipagina:
            texto_corpus = scraper.obtener_texto_multipagina()
            
        else:
            texto_corpus = datos_corpus.get("text", "")

            
        if not texto_corpus:
            print("No se pudo extraer texto del corpus.")
            scraper.actualizo_csv(
                url,
                "extraccion",
                "Sin texto"
            )
            continue

        datos_normalizados = scraper.normalizar(
            texto_corpus
        )

        scraper.actualizo_csv(
            url,
            "normalizacion",
            "OK"
        )
        resultado = scraper.tokenizar_documentos([datos_normalizados])
        print("Resultado de la tokenización:", resultado)
        scraper.actualizo_csv(
            url,
            "Cant-Tokens",
            resultado
        )
        
        scraper.actualizo_csv(
            url,
            "Licencia",
            datos_corpus.get("license", "")
        )
        
        datos_sin_stopwords = scraper.palabras_significativas(
            texto_corpus,
            stopwords
        )

        print(
            "Datos del corpus sin stopwords: "
            f"{datos_sin_stopwords[:100]}..."
        )

        scraper.guardar_datos_corpus(
            datos_normalizados,
            tipo_dato="texto",
            tipo_archivo="normalizado"
        )
        
        scraper.actualizo_csv(
            url,
            "guardado",
            "OK"
        )    

if __name__ == "__main__":
    main()

# %%
from scraper_actualizado import Scraper as Scraper_1

scraper_1 = Scraper_1(
    url="https://es.wikisource.org",
    carpeta_destino="datos"
)
scraper_1.generar_corpus_jsonl()
# Out:
# Corpus generado en: C:\Ciencia De Datos\NLP\pair_programming_ia\datos\corpus.jsonl
# Documentos guardados: 12

# %%
import json

def analizar_dispersion_longitud(ruta_corpus="datos/corpus.jsonl"):
    """
    Calcula la cantidad de tokens de cada documento
    utilizando len(texto.split()).
    """

    cantidades = []

    with open(ruta_corpus, "r", encoding="utf-8") as archivo:

        for linea in archivo:

            documento = json.loads(linea)

            cantidad_tokens = len(documento["texto"].split())

            cantidades.append(cantidad_tokens)

            print(
                f"{documento['id']} | "
                f"{documento['titulo']} | "
                f"{cantidad_tokens} tokens"
            )

    print("\n--- RESUMEN ---")
    print(f"Cantidad de documentos: {len(cantidades)}")
    print(f"Mínimo: {min(cantidades)} tokens")
    print(f"Máximo: {max(cantidades)} tokens")
    print(f"Diferencia: {max(cantidades) - min(cantidades)} tokens")
    print(f"Promedio: {sum(cantidades) / len(cantidades):.2f} tokens")
analizar_dispersion_longitud()
# Out:
# doc_01 | Caramurú - Wikisource | 48766 tokens
# doc_02 | Doña Luz - Wikisource | 59381 tokens
# doc_03 | A flor de piel - Wikisource | 60849 tokens
# doc_04 | Don Segundo Sombra - Wikisource | 61274 tokens
# doc_05 | A fuego lento - Wikisource | 64006 tokens
# doc_06 | Dulce dueño (Pardo Bazán) - Wikisource | 66584 tokens
# doc_07 | Crónica del reinado de Carlos IX - Wikisource | 66868 tokens
# doc_08 | Doña Milagros - Wikisource | 67790 tokens
# doc_09 | De Cartago a Sagunto - Wikisource | 68103 tokens
# doc_10 | Aurora roja - Wikisource | 69763 tokens
# doc_11 | Carlos VI en la Rápita - Wikisource | 70053 tokens
# doc_12 | Cañas y barro - Wikisource | 74953 tokens
#
# --- RESUMEN ---
# Cantidad de documentos: 12
# Mínimo: 48766 tokens
# Máximo: 74953 tokens
# Diferencia: 26187 tokens
# Promedio: 64865.83 tokens

# %%
import json
import re

def revisar_artefactos(ruta_corpus="datos/corpus.jsonl"):
    
    with open(ruta_corpus, "r", encoding="utf-8") as archivo:

        for linea in archivo:
            documento = json.loads(linea)

            texto = documento["texto"]

            html = re.findall(r"<[^>]+>", texto)
            javascript = re.findall(
                r"\b(function|var|let|const|script)\b",
                texto,
                flags=re.IGNORECASE
            )

            espacios_duros = texto.count("\xa0")

            print(
                f"{documento['id']} | "
                f"{documento['titulo']}"
            )

            print(f"Espacios duros: {espacios_duros}")
            print(f"Restos HTML: {len(html)}")
            print(f"Posibles restos JS: {len(javascript)}")
            print("-" * 50)
revisar_artefactos()
# Out:
# doc_01 | Caramurú - Wikisource
# Espacios duros: 0
# Restos HTML: 0
# Posibles restos JS: 0
# --------------------------------------------------
# doc_02 | Doña Luz - Wikisource
# Espacios duros: 0
# Restos HTML: 0
# Posibles restos JS: 0
# --------------------------------------------------
# doc_03 | A flor de piel - Wikisource
# Espacios duros: 0
# Restos HTML: 0
# Posibles restos JS: 0
# --------------------------------------------------
# doc_04 | Don Segundo Sombra - Wikisource
# Espacios duros: 0
# Restos HTML: 0
# Posibles restos JS: 0
# --------------------------------------------------
# doc_05 | A fuego lento - Wikisource
# Espacios duros: 0
# Restos HTML: 0
# Posibles restos JS: 0
# --------------------------------------------------
# doc_06 | Dulce dueño (Pardo Bazán) - Wikisource
# Espacios duros: 0
# Restos HTML: 0
# Posibles restos JS: 0
# --------------------------------------------------
# doc_07 | Crónica del reinado de Carlos IX - Wikisource
# Espacios duros: 0
# ...

# %% [markdown]
# #Sergio Tareas 3.1, 3.2, 3.3

# %%
# pandas: para trabajar el corpus como tabla.
import pandas as pd

# Counter: para contar cosas. Devuelve un diccionario palabra -> veces.
from collections import Counter

corpus = pd.read_json("datos/corpus.jsonl", lines=True)

print("textos:", f"{len(corpus):,}")
# Out:
# textos: 12

# %%
# string: trae la lista de signos de puntuación.
import string
import re

signos_del_espanol = "¡¿—–…“”‘’«»"
todos_los_signos = string.punctuation + signos_del_espanol

# re.escape prepara los signos para que la expresión regular los tome literalmente.
patron_de_signos = "[" + re.escape(todos_los_signos) + "]"

def limpiar(texto):
    # Pasa a minúsculas, saca la puntuación y unifica los espacios.
    # NO saca números: en este corpus los años son datos.
    en_minusculas = texto.lower()
    sin_signos = re.sub(patron_de_signos, " ", en_minusculas)
    sin_espacios_de_mas = re.sub(r"\s+", " ", sin_signos)
    return sin_espacios_de_mas.strip()

# %%
corpus.head(5)
# Out:
#        id                           titulo                          autor  \
# 0  doc_01            Caramurú - Wikisource  Alejandro Magariños Cervantes
# 1  doc_02            Doña Luz - Wikisource                    Juan Valera
# 2  doc_03      A flor de piel - Wikisource      Antonio de Hoyos y Vinent
# 3  doc_04  Don Segundo Sombra - Wikisource         AutorRicardo Güiraldes
# 4  doc_05       A fuego lento - Wikisource               Emilio Bobadilla
#
#    fecha                                         fuente_url categoria  \
# 0   1865       https://es.wikisource.org/wiki/Caramur%C3%BA    Novela
# 1   1879       https://es.wikisource.org/wiki/Do%C3%B1a_Luz    Novela
# 2   1907      https://es.wikisource.org/wiki/A_flor_de_piel    Novela
# 3   1927  https://es.wikisource.org/wiki/Don_Segundo_Sombra    Novela
# 4   1903       https://es.wikisource.org/wiki/A_fuego_lento    Novela
#
#                                                texto
# ...

# %%
tex1=corpus.loc[0,"texto"]
tex1
# Out:
# 'Caramurú/Advertencia\nApariencia\n \n \n< Caramurú\nAdvertencia\nAunque esta no sea una novela histórica ni tenga las pretensiones de tal, sus personajes no pueden considerarse absolutamente como hijos de la imaginación.\nNos daremos por muy felices, no obstante, si a favor de una fábula que interese agradablemente al lector y excite sus nobles sentimientos, conseguimos bosquejar algunos rasgos del país, de la época y de los personajes que figuran en este libro.\nA. Magariños Cervantes,\nMadrid-1848.\n\nCaramurú/Capítulo I\nCapítulo I\nEl rapto\nLóbrega y pavorosa noche extiende sus alas sobre el mundo, como una inmensa lápida mortuoria. No se descubre una sola estrella al través de su ennegrecido velo: la luna, yace oculta bajo un pabellón de nubes, y solo lanza a intervalos un rayo de luz tibio y desmayado, que brilla y se apaga al punto, cual fuego fatuo que se levanta del seno de las tumbas. Do quiera la luz es absorbida por la sombra, y se diría que a la voz del genio de las ti
# ...

# %%
tex1_limpio=limpiar(tex1)
tex1_limpio
# Out:
# 'caramurú advertencia apariencia caramurú advertencia aunque esta no sea una novela histórica ni tenga las pretensiones de tal sus personajes no pueden considerarse absolutamente como hijos de la imaginación nos daremos por muy felices no obstante si a favor de una fábula que interese agradablemente al lector y excite sus nobles sentimientos conseguimos bosquejar algunos rasgos del país de la época y de los personajes que figuran en este libro a magariños cervantes madrid 1848 caramurú capítulo i capítulo i el rapto lóbrega y pavorosa noche extiende sus alas sobre el mundo como una inmensa lápida mortuoria no se descubre una sola estrella al través de su ennegrecido velo la luna yace oculta bajo un pabellón de nubes y solo lanza a intervalos un rayo de luz tibio y desmayado que brilla y se apaga al punto cual fuego fatuo que se levanta del seno de las tumbas do quiera la luz es absorbida por la sombra y se diría que a la voz del genio de las tinieblas los astros huyen y se esconden e
# ...

# %%
# La aplicamos a todo el corpus.
textos_limpios = []
for texto in corpus["texto"]:
    textos_limpios.append(limpiar(texto))

corpus["texto_limpio"] = textos_limpios

corpus.head(3)
# Out:
#        id                       titulo                          autor  fecha  \
# 0  doc_01        Caramurú - Wikisource  Alejandro Magariños Cervantes   1865
# 1  doc_02        Doña Luz - Wikisource                    Juan Valera   1879
# 2  doc_03  A flor de piel - Wikisource      Antonio de Hoyos y Vinent   1907
#
#                                       fuente_url categoria  \
# 0   https://es.wikisource.org/wiki/Caramur%C3%BA    Novela
# 1   https://es.wikisource.org/wiki/Do%C3%B1a_Luz    Novela
# 2  https://es.wikisource.org/wiki/A_flor_de_piel    Novela
#
#                                                texto  \
# 0  Caramurú/Advertencia\nApariencia\n \n \n< Cara...
# 1  Doña Luz/A la señora condesa de Gomar\nA la se...
# 2  A flor de piel/01\nApariencia\n \n \nÉpigraphe...
#
#                                         texto_limpio
# 0  caramurú advertencia apariencia caramurú adver...
# 1  doña luz a la señora condesa de gomar a la señ...
# ...

# %%
corpus.head(6)
# Out:
#        id                                  titulo  \
# 0  doc_01                   Caramurú - Wikisource
# 1  doc_02                   Doña Luz - Wikisource
# 2  doc_03             A flor de piel - Wikisource
# 3  doc_04         Don Segundo Sombra - Wikisource
# 4  doc_05              A fuego lento - Wikisource
# 5  doc_06  Dulce dueño (Pardo Bazán) - Wikisource
#
#                            autor  fecha  \
# 0  Alejandro Magariños Cervantes   1865
# 1                    Juan Valera   1879
# 2      Antonio de Hoyos y Vinent   1907
# 3         AutorRicardo Güiraldes   1927
# 4               Emilio Bobadilla   1903
# 5             Emilia Pardo Bazán   1911
#
#                                           fuente_url categoria  \
# 0       https://es.wikisource.org/wiki/Caramur%C3%BA    Novela
# 1       https://es.wikisource.org/wiki/Do%C3%B1a_Luz    Novela
# 2      https://es.wikisource.org/wiki/A_flor_de_piel    Novela
# 3  https://es.wikisource.org/wiki/Don_Segundo_Sombra    Novela
# ...

# %%
todo_el_corpus = " ".join(corpus["texto"])

palabras = todo_el_corpus.split()

conteo = Counter(palabras)

print("palabras en total  :", f"{len(palabras):,}")
print("palabras distintas :", f"{len(conteo):,}")
print()
print("las 15 más frecuentes:")
for palabra, veces in conteo.most_common(15):
    print(" ", palabra, "->", veces)
# Out:
# palabras en total  : 778,390
# palabras distintas : 102,772
#
# las 15 más frecuentes:
#   de -> 41274
#   la -> 25807
#   que -> 23897
#   y -> 23164
#   el -> 18183
#   en -> 16507
#   a -> 15677
#   los -> 10180
#   se -> 9367
#   con -> 8761
#   un -> 8482
#   no -> 8084
#   su -> 7437
#   las -> 7348
#   por -> 6710

# %%
todo_limpio = " ".join(corpus["texto_limpio"])
palabras_limpias = todo_limpio.split()
conteo_limpio = Counter(palabras_limpias)

print("antes  ->", f"{len(conteo):,}", "palabras distintas")
print("después->", f"{len(conteo_limpio):,}", "palabras distintas")
print()
reduccion = 100 * (1 - len(conteo_limpio) / len(conteo))
print("el vocabulario se achicó un", f"{reduccion:.0f}%")
# Out:
# antes  -> 102,772 palabras distintas
# después-> 54,559 palabras distintas
#
# el vocabulario se achicó un 47%

# %%
archivo = open("stopwords_es.txt", encoding="utf-8")
contenido = archivo.read()
archivo.close()

palabras_vacias = contenido.split()

# %%
print(palabras_vacias[:20])
# Out:
# ['a', 'al', 'algo', 'algunas', 'algunos', 'ante', 'antes', 'como', 'cómo', 'con', 'contra', 'cual', 'cuando', 'de', 'del', 'desde', 'donde', 'durante', 'e', 'el']

# %%
palabras_con_contenido = []
for palabra in palabras_limpias:
    if palabra in palabras_vacias:
        continue
    if len(palabra) < 3:
        continue
    palabras_con_contenido.append(palabra)

conteo_final = Counter(palabras_con_contenido)
total_palabras = len(palabras_con_contenido)

print("las 20 más frecuentes:")
for palabra, veces in conteo_final.most_common(20):
    frecuencia_relativa = veces / total_palabras
    print(" ", palabra, "->", veces, f"({frecuencia_relativa:.2%})")
# Out:
# las 20 más frecuentes:
#   había -> 2497 (0.63%)
#   usted -> 1587 (0.40%)
#   dijo -> 1429 (0.36%)
#   tan -> 1269 (0.32%)
#   dos -> 1251 (0.32%)
#   don -> 1096 (0.28%)
#   bien -> 1055 (0.27%)
#   hombre -> 1009 (0.26%)
#   doña -> 992 (0.25%)
#   ser -> 977 (0.25%)
#   casa -> 962 (0.24%)
#   vez -> 933 (0.24%)
#   vida -> 914 (0.23%)
#   después -> 895 (0.23%)
#   ojos -> 869 (0.22%)
#   pues -> 862 (0.22%)
#   aquel -> 811 (0.21%)
#   luz -> 796 (0.20%)
#   así -> 747 (0.19%)
#   señor -> 704 (0.18%)

# %%
docus = sorted(corpus["id"].unique())

documentos_por_id = []
for docu in docus:
    parrafos_del_texto = corpus[corpus["id"] == docu]
    texto_del_ = " ".join(parrafos_del_texto["texto_limpio"])
    documentos_por_id.append(texto_del_)

print("documentos:", len(documentos_por_id))
print()
for posicion in range(len(docus)):
    palabras = len(documentos_por_id[posicion].split())
    print(docus[posicion], "->", f"{palabras:,}", "palabras")
# Out:
# documentos: 12
#
# doc_01 -> 48,788 palabras
# doc_02 -> 59,432 palabras
# doc_03 -> 60,874 palabras
# doc_04 -> 61,421 palabras
# doc_05 -> 64,133 palabras
# doc_06 -> 66,493 palabras
# doc_07 -> 65,317 palabras
# doc_08 -> 67,825 palabras
# doc_09 -> 68,172 palabras
# doc_10 -> 69,821 palabras
# doc_11 -> 70,166 palabras
# doc_12 -> 75,052 palabras

# %%
from sklearn.feature_extraction.text import CountVectorizer

# min_df=2 descarta las palabras que aparecen en un solo documento.
# Es una decisión: reduce el ruido y también borra lo muy específico.
contador = CountVectorizer(stop_words=palabras_vacias, min_df=2)

matriz = contador.fit_transform(documentos_por_id)

print("forma de la matriz:", matriz.shape)
print("   12 documentos por", f"{matriz.shape[1]:,}", "palabras distintas")
# Out:
# forma de la matriz: (12, 24047)
#    12 documentos por 24,047 palabras distintas

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizador = TfidfVectorizer(stop_words=palabras_vacias, min_df=2)
pesos = vectorizador.fit_transform(documentos_por_id)

vocabulario = vectorizador.get_feature_names_out()
tabla_pesos = pesos.toarray()

# Para cada documento, las seis palabras con más peso.
filas = []
for posicion in range(len(docus)):
    pesos_del_documento = tabla_pesos[posicion]
    orden = np.argsort(pesos_del_documento)
    mejores = []
    for indice in orden[-6:]:
        mejores.append(vocabulario[indice])
    mejores.reverse()
    fila = {"documento": docus[posicion], "palabras_con_mas_peso": ", ".join(mejores)}
    filas.append(fila)

pd.DataFrame(filas)
# Out:
#    documento                          palabras_con_mas_peso
# 0     doc_01             gaucho, si, había, conde, dos, vez
# 1     doc_02             doña, luz, jaime, había, si, padre
# 2     doc_03           lina, había, si, ojos, vida, aquella
# 3     doc_04           había, pa, don, si, segundo, padrino
# 4     doc_05      baranda, usted, doctor, si, nicasia, dijo
# 5     doc_06          catalina, usted, si, ha, carranza, he
# 6     doc_07  dijo, si, capitán, almirante, había, bernardo
# 7     doc_08         usted, si, argos, milagros, usté, doña
# 8     doc_09             don, usted, si, dijo, había, señor
# 9     doc_10       manuel, dijo, salvadora, juan, había, si
# 10    doc_11                   si, había, ha, tan, vi, pues
# 11    doc_12          había, palmar, lago, si, tío, taberna

# %%
idf_por_documentos = np.round(vectorizador.idf_, 3)

print("términos en el vocabulario:", f"{len(idf_por_documentos):,}")
print("valores de IDF distintos  :", len(set(idf_por_documentos)))
# Out:
# términos en el vocabulario: 24,047
# valores de IDF distintos  : 11

# %%
reparto = Counter(idf_por_documentos)

filas = []
for valor in sorted(reparto):
    fila = {"idf": valor, "cuantos_terminos": reparto[valor]}
    filas.append(fila)

pd.DataFrame(filas)
# Out:
#       idf  cuantos_terminos
# 0   1.000               777
# 1   1.080               510
# 2   1.167               610
# 3   1.262               661
# 4   1.368               798
# 5   1.486              1067
# 6   1.619              1398
# 7   1.773              1932
# 8   1.956              2836
# 9   2.179              4650
# 10  2.466              8808

# %%
vectorizador_parrafos = TfidfVectorizer(stop_words=palabras_vacias, min_df=2)
vectorizador_parrafos.fit(corpus["texto_limpio"])

idf_por_parrafos = np.round(vectorizador_parrafos.idf_, 3)

filas = [
    {
        "unidad": "documento",
        "documentos": len(documentos_por_id),
        "terminos": len(idf_por_documentos),
        "valores_de_idf": len(set(idf_por_documentos)),
    },
    {
        "unidad": "párrafo",
        "documentos": len(corpus),
        "terminos": len(idf_por_parrafos),
        "valores_de_idf": len(set(idf_por_parrafos)),
    },
]

pd.DataFrame(filas)
# Out:
#       unidad  documentos  terminos  valores_de_idf
# 0  documento          12     24047              11
# 1    párrafo          12     24047              11

# %%
import json
import spacy
import pandas as pd

# Cargar modelo de español
nlp = spacy.load("es_core_news_lg")

# Ruta del corpus
ruta_corpus = "datos/corpus.jsonl"

resultados = []

with open(ruta_corpus, "r", encoding="utf-8") as archivo:

    for linea in archivo:

        documento = json.loads(linea)

        texto = documento["texto"]

        # Procesamiento lingüístico con spaCy
        doc = nlp(texto)

        # Solo tokens que sean palabras:
        # excluimos puntuación y espacios
        palabras = [
            token
            for token in doc
            if not token.is_punct and not token.is_space
        ]

        total_palabras = len(palabras)

        # Conteo POS
        cantidad_adjetivos = sum(
            1 for token in palabras
            if token.pos_ == "ADJ"
        )

        cantidad_adverbios = sum(
            1 for token in palabras
            if token.pos_ == "ADV"
        )

        # Frecuencias relativas
        frecuencia_adj = (
            cantidad_adjetivos / total_palabras
            if total_palabras > 0 else 0
        )

        frecuencia_adv = (
            cantidad_adverbios / total_palabras
            if total_palabras > 0 else 0
        )

        resultados.append({
            "id": documento["id"],
            "titulo": documento["titulo"],
            "total_palabras": total_palabras,
            "adjetivos": cantidad_adjetivos,
            "adverbios": cantidad_adverbios,
            "fr_adj": frecuencia_adj,
            "fr_adv": frecuencia_adv,
            "adj_mayor_adv": frecuencia_adj > frecuencia_adv
        })


# Convertir resultados a DataFrame
df_resultados = pd.DataFrame(resultados)

# Mostrar porcentajes con más claridad
df_resultados["fr_adj_pct"] = (
    df_resultados["fr_adj"] * 100
).round(2)

df_resultados["fr_adv_pct"] = (
    df_resultados["fr_adv"] * 100
).round(2)

# Columnas finales para visualizar
columnas_mostrar = [
    "id",
    "titulo",
    "total_palabras",
    "adjetivos",
    "adverbios",
    "fr_adj_pct",
    "fr_adv_pct",
    "adj_mayor_adv"
]

display(df_resultados[columnas_mostrar])
# Out:
#         id                                         titulo  total_palabras  \
# 0   doc_01                          Caramurú - Wikisource           48782
# 1   doc_02                          Doña Luz - Wikisource           59401
# 2   doc_03                    A flor de piel - Wikisource           60802
# 3   doc_04                Don Segundo Sombra - Wikisource           61205
# 4   doc_05                     A fuego lento - Wikisource           64006
# 5   doc_06         Dulce dueño (Pardo Bazán) - Wikisource           66459
# 6   doc_07  Crónica del reinado de Carlos IX - Wikisource           65207
# 7   doc_08                     Doña Milagros - Wikisource           67788
# 8   doc_09              De Cartago a Sagunto - Wikisource           68132
# 9   doc_10                       Aurora roja - Wikisource           69794
# 10  doc_11            Carlos VI en la Rápita - Wikisource           70084
# 11  doc_12                     Cañas y barro - Wikisource           74960
#
# ...

# %%
documentos_cumplen = df_resultados[
    "adj_mayor_adv"
].sum()

total_documentos = len(df_resultados)

print(
    f"Documentos donde ADJ > ADV: "
    f"{documentos_cumplen} de {total_documentos}"
)

print(
    f"Documentos donde ADJ <= ADV: "
    f"{total_documentos - documentos_cumplen}"
)

promedio_adj = (
    df_resultados["fr_adj"].mean() * 100
)

promedio_adv = (
    df_resultados["fr_adv"].mean() * 100
)

print(
    f"Frecuencia relativa media de adjetivos: "
    f"{promedio_adj:.2f}%"
)

print(
    f"Frecuencia relativa media de adverbios: "
    f"{promedio_adv:.2f}%"
)
# Out:
# Documentos donde ADJ > ADV: 12 de 12
# Documentos donde ADJ <= ADV: 0
# Frecuencia relativa media de adjetivos: 7.37%
# Frecuencia relativa media de adverbios: 4.83%

# %%
import matplotlib.pyplot as plt
import numpy as np

# Posición de cada documento en el eje X
x = np.arange(len(df_resultados))

# Ancho de las barras
ancho = 0.35

# Crear gráfico
plt.figure(figsize=(15, 7))

plt.bar(
    x - ancho / 2,
    df_resultados["fr_adj_pct"],
    width=ancho,
    label="Adjetivos"
)

plt.bar(
    x + ancho / 2,
    df_resultados["fr_adv_pct"],
    width=ancho,
    label="Adverbios"
)

# Configuración de los ejes
plt.xticks(
    x,
    df_resultados["id"],
    rotation=45
)

plt.xlabel("Documentos")
plt.ylabel("Frecuencia relativa (%)")

# El eje Y comienza en cero, como exige la consigna
plt.ylim(bottom=0)

# Título orientado al hallazgo
plt.title(
    "Los adjetivos presentan mayor frecuencia relativa "
    "que los adverbios en los 12 textos del corpus"
)

plt.legend()

plt.tight_layout()
plt.show()

# %%
import json
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Cargar corpus
documentos = []

with open("datos/corpus.jsonl", "r", encoding="utf-8") as archivo:
    for linea in archivo:
        documento = json.loads(linea)
        documentos.append(documento)

# Unir todos los textos
texto_corpus = ""

for documento in documentos:
    texto_corpus += " " + documento["texto"]


# Cargar palabras vacías
palabras_vacias = set()

with open("stopwords_es.txt", "r", encoding="utf-8") as archivo:
    for linea in archivo:
        palabra = linea.strip().lower()

        if palabra:
            palabras_vacias.add(palabra)


# Generar nube
nube = WordCloud(
    width=1200,
    height=600,
    background_color="white",
    stopwords=palabras_vacias
).generate(texto_corpus)


# Mostrar
plt.figure(figsize=(15, 7))

plt.imshow(
    nube,
    interpolation="bilinear"
)

plt.axis("off")

plt.title(
    "Palabras más frecuentes en el corpus"
)

plt.show()
print(
    "La nube de palabras, por sí sola, no permite determinar la frecuencia "
    "relativa de adjetivos y adverbios, pero permite visualizar las palabras "
    "más frecuentes del corpus."
)
# Out:
# La nube de palabras, por sí sola, no permite determinar la frecuencia relativa de adjetivos y adverbios, pero permite visualizar las palabras más frecuentes del corpus.

# %%
import matplotlib.pyplot as plt

# Obtener las 20 palabras más frecuentes
top_20 = conteo_final.most_common(20)

palabras_grafico = []
frecuencias_relativas = []

for palabra, veces in top_20:
    palabras_grafico.append(palabra)

    frecuencia_relativa = veces / total_palabras
    frecuencias_relativas.append(frecuencia_relativa * 100)


# Crear gráfico
plt.figure(figsize=(12, 6))

plt.bar(
    palabras_grafico,
    frecuencias_relativas
)

plt.title(
    "Las 20 palabras de contenido más frecuentes concentran distintas proporciones del corpus"
)

plt.xlabel("Palabras")
plt.ylabel("Frecuencia relativa (%)")

# La consigna exige que el eje de frecuencia relativa comience en cero
plt.ylim(bottom=0)

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
